# %%
import matplotlib.pyplot as plt
from skimage import io, color



# Load ảnh
image = plt.imread('D:\KHOA_HOC_2022-2023\THUC_TAP_XULIANH\FILE_VIDEO\ROCKET.jpg')

# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)

# Obtaining the red values of the image
red = image[:, :, 0]

# Obtaining the green values of the image
green = image[:, :, 1]

# Obtaining the blue values of the image
blue = image[:, :, 2]

plt.figure()
plt.imshow(red)
plt.title('Red')
plt.axis('off')


plt.figure()
plt.imshow(green)
plt.title('Green')
plt.axis('off')


plt.figure()
plt.imshow(blue)
plt.title('Blue')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import io, color

# %%
# Load ảnh
image = plt.imread('D:\KHOA_HOC_2022-2023\THUC_TAP_XULIANH\FILE_VIDEO\ROCKET.jpg')
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load ảnh
# ----> 2 image = plt.imread('D:\KHOA_HOC_2022-2023\THUC_TAP_XULIANH\FILE_VIDEO\ROCKET.jpg')
#       3 plt.imshow(image)
#
# File D:\KHOA_HOC_2022-2023\THUC_TAP_XULIANH\INSTALL_ANACONDA\lib\site-packages\matplotlib\pyplot.py:2168, in imread(fname, format)
#    2166 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2167 def imread(fname, format=None):
# -> 2168     return matplotlib.image.imread(fname, format)
#
# File D:\KHOA_HOC_2022-2023\THUC_TAP_XULIANH\INSTALL_ANACONDA\lib\site-packages\matplotlib\image.py:1561, in imread(fname, format)
#    1554 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1555     # Pillow doesn't handle URLs directly.
#    1556     raise ValueError(
#    1557         "Please open the URL for reading and pass the "
# ...

# %%
import matplotlib.pyplot as plt
from skimage import io, color



# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')

# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)

# Obtaining the red values of the image
red = image[:, :, 0]

# Obtaining the green values of the image
green = image[:, :, 1]

# Obtaining the blue values of the image
blue = image[:, :, 2]

plt.figure() ## tách anh rieng
plt.imshow(red)
plt.title('Red')
plt.axis('off')


plt.figure()
plt.imshow(green)
plt.title('Green')
plt.axis('off')


plt.figure()
plt.imshow(blue)
plt.title('Blue')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import io, color

# %%
# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)
plt.imshow(image)

# %%
# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)

plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load ảnh
# ----> 2 image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
#       3 # Chuyển ảnh từ RGB sang LAB
#       4 grayscale = color.rgb2gray(image)
#
# NameError: name 'plt' is not defined

# %%
# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load ảnh
# ----> 2 image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
#       3 # Chuyển ảnh từ RGB sang LAB
#       4 grayscale = color.rgb2gray(image)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
from skimage import io, color

# %%
# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
plt.imshow(image)
type(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Load ảnh
# ----> 2 image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')
#       3 # Chuyển ảnh từ RGB sang LAB
#       4 grayscale = color.rgb2gray(image)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
from skimage import io, color



# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')

# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)

# Obtaining the red values of the image
red = image[:, :, 0]

# Obtaining the green values of the image
green = image[:, :, 1]

# Obtaining the blue values of the image
blue = image[:, :, 2]

plt.figure() ## tách anh rieng
plt.imshow(red)
plt.title('Red')
plt.axis('off')


plt.figure()
plt.imshow(green)
plt.title('Green')
plt.axis('off')


plt.figure()
plt.imshow(blue)
plt.title('Blue')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import io, color

# %%
# Load ảnh
image = plt.imread('D:\\KHOA_HOC_2022-2023\\THUC_TAP_XULIANH\\BAI_TAP\\ROCKET.jpg')

# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
plt.imshow(blue)
plt.axis('off')
type(image)
# Out:
# numpy.ndarray

# %%
# Obtaining the red values of the image
red = image[:, :, 0]
plt.figure() ## tách anh rieng
plt.imshow(red,cmap = 'gray')
plt.title('Red')
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
# Obtaining the red values of the image
red = image[:, :, 1]
plt.figure() ## tách anh rieng
plt.imshow(red,cmap = 'gray')
plt.title('Green')
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
# Obtaining the red values of the image
red = image[:, :, 2]
plt.figure() ## tách anh rieng
plt.imshow(red,cmap = 'gray')
plt.title('Blue')
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)
